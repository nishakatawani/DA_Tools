# %% [markdown]
#  ### pandas
#
#  >pandas is a powerfull python library for manipulation and analysis of data
#
#  >its a open source library
#
#  >fast(built on top of numpy) , flexible(different resource), productive library

# %% [markdown]
# #### Install

# %%
 pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# #### Series - one dimensional array (data structure)with label

# %%
l1 = [1,2,3,4,5]
type(l1)
# Out:
# list

# %%
pd.Series(l1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series(l1, index=["a","b","c","d","e"], name ="my series")
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: my series, dtype: int64

# %%
s=pd.Series(l1, index=["a","b","c","d","e"], name ="my series")

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: my series, dtype: int64

# %%
s['a']
# Out:
# np.int64(1)

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
s.values
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# Note : index in series are immutable(cant change)

# %%
s.index[0] = 'z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s.index[0] = 'z'
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5371, in Index.__setitem__(self, key, value)
#    5369 @final
#    5370 def __setitem__(self, key, value) -> None:
# -> 5371     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
# changing the index of pandas series

s.rename(index={'b':'y'},inplace=True)

# %%
s
# Out:
# a    1
# y    2
# c    3
# d    4
# e    5
# Name: my series, dtype: int64

# %% [markdown]
# ### DataFrame - its a 2d array (just like tables)

# %% [markdown]
# rows and cols

# %%
dict1={'Name':['virat','rohit','dhoni','jadeja','bumrah','virat'] ,
        'age':[34,33,40,32,30,28] ,
        'Marks':[85,90,75,80,70,80] ,
        'role':['Batsman','Batsman','Wicket keeper','All rounder','Bowler','bowler']
        }

df=pd.DataFrame(dict1)

# %%
df
# Out:
#      Name  age  Marks           role
# 0   virat   34     85        Batsman
# 1   rohit   33     90        Batsman
# 2   dhoni   40     75  Wicket keeper
# 3  jadeja   32     80    All rounder
# 4  bumrah   30     70         Bowler
# 5   Shami   28     80         bowler

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head
# Out:
# <bound method NDFrame.head of      Name  age  Marks           role
# 0   virat   34     85        Batsman
# 1   rohit   33     90        Batsman
# 2   dhoni   40     75  Wicket keeper
# 3  jadeja   32     80    All rounder
# 4  bumrah   30     70         Bowler
# 5   Shami   28     80         bowler>

# %%
df.tail
# Out:
# <bound method NDFrame.tail of      Name  age  Marks           role
# 0   virat   34     85        Batsman
# 1   rohit   33     90        Batsman
# 2   dhoni   40     75  Wicket keeper
# 3  jadeja   32     80    All rounder
# 4  bumrah   30     70         Bowler
# 5   Shami   28     80         bowler>

# %%
len(df)
# Out:
# 6

# %%
df.count()
# Out:
# Name     6
# age      6
# Marks    6
# role     6
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'age', 'Marks', 'role'], dtype='object')

# %%
df['Name']
# Out:
# 0     virat
# 1     rohit
# 2     dhoni
# 3    jadeja
# 4    bumrah
# 5     Shami
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df['Name'].value_counts()
# Out:
# Name
# virat     2
# rohit     1
# dhoni     1
# jadeja    1
# bumrah    1
# Name: count, dtype: int64

# %%
df=pd.DataFrame(dict1)
df
# Out:
#      Name  age  Marks           role
# 0   virat   34     85        Batsman
# 1   rohit   33     90        Batsman
# 2   dhoni   40     75  Wicket keeper
# 3  jadeja   32     80    All rounder
# 4  bumrah   30     70         Bowler
# 5   virat   28     80         bowler

# %%
df.size
# Out:
# 24

# %% [markdown]
# ##basic opretions

# %% [markdown]
# >improting data set from different files
#
# >importing tabular data set

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\klemp\Desktop\DataAnalyst(nisha)\data set\ETH_1h.csv")

# %%
df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
stock_df=pd.read_csv(r"C:\Users\klemp\Desktop\DataAnalyst(nisha)\data set\ETH_1h.csv")

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %% [markdown]
# by defuault head()will return first five rows

# %%
stock_df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %% [markdown]
# head(10)it will return first ten rows

# %%
stock_df.head(10)
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# 5  2020-03-13 03-PM  ETHUSD  128.39  128.90  116.06  124.85  7378976.00
# 6  2020-03-13 02-PM  ETHUSD  134.03  137.90  125.50  128.39  3733916.89
# 7  2020-03-13 01-PM  ETHUSD  131.35  140.95  128.99  134.03  9582732.93
# 8  2020-03-13 12-PM  ETHUSD  128.93  134.60  126.95  131.35  3906590.52
# 9  2020-03-13 11-AM  ETHUSD  132.60  133.17  126.01  128.93  3311080.29

# %% [markdown]
# bottom five rows

# %%
stock_df.tail()
# Out:
#                    Date  Symbol    Open    High    Low   Close      Volume
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.0  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.0  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.0  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.0  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.1  275.01   679358.87

# %% [markdown]
# len is used to get number of rows

# %%
len(stock_df)
# Out:
# 23674

# %% [markdown]
# Accss columns name of dataframe

# %%
stock_df.columns
# Out:
# Index(['Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
##accessing a column in a Datasframe

stock_df['Open']
# Out:
# 0        129.94
# 1        119.51
# 2        124.47
# 3        124.08
# 4        124.85
#           ...
# 23669    265.74
# 23670    268.79
# 23671    274.83
# 23672    275.01
# 23673    279.98
# Name: Open, Length: 23674, dtype: float64

# %%
##accessing a column in a Datasframe

stock_df[['Open','Close']]
# Out:
#          Open   Close
# 0      129.94  128.71
# 1      119.51  129.94
# 2      124.47  119.51
# 3      124.08  124.47
# 4      124.85  124.08
# ...       ...     ...
# 23669  265.74  272.57
# 23670  268.79  265.74
# 23671  274.83  268.79
# 23672  275.01  274.83
# 23673  279.98  275.01
#
# [23674 rows x 2 columns]

# %%
##accssing multiple  columns use array
stock_df[['Open','Symbol','High']]
# Out:
#          Open  Symbol    High
# 0      129.94  ETHUSD  131.82
# 1      119.51  ETHUSD  132.02
# 2      124.47  ETHUSD  124.85
# 3      124.08  ETHUSD  127.42
# 4      124.85  ETHUSD  129.51
# ...       ...     ...     ...
# 23669  265.74  ETHUSD  272.74
# 23670  268.79  ETHUSD  269.90
# 23671  274.83  ETHUSD  274.93
# 23672  275.01  ETHUSD  275.01
# 23673  279.98  ETHUSD  279.99
#
# [23674 rows x 3 columns]

# %% [markdown]
# indexing loc

# %%
stock_df.index
# Out:
# RangeIndex(start=0, stop=23674, step=1)

# %%
stock_df.columns
# Out:
# Index(['Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %% [markdown]
# loc-lable location

# %%
df.loc[23567]
# Out:
# Date      2017-07-05 09-PM
# Symbol              ETHUSD
# Open                 265.2
# High                268.27
# Low                  263.4
# Close               267.99
# Volume          1373223.25
# Name: 23567, dtype: object

# %%
df.loc[23567,Close:Open]]
# Out:
#   Cell In[87], line 1
#     df.loc[23567,Close:Open]]
#                             ^
# SyntaxError: unmatched ']'

# %%
df.loc[1]
# Out:
# Date      2020-03-13 07-PM
# Symbol              ETHUSD
# Open                119.51
# High                132.02
# Low                  117.1
# Close               129.94
# Volume          7579741.09
# Name: 1, dtype: object

# %%
stock_df.iloc[5]
# Out:
# Date      2020-03-13 03-PM
# Symbol              ETHUSD
# Open                128.39
# High                 128.9
# Low                 116.06
# Close               124.85
# Volume           7378976.0
# Name: 5, dtype: object

# %%
stock_df.loc[0:10,['Date','High','Open','Symbol']]
# Out:
#                 Date    High    Open  Symbol
# 0   2020-03-13 08-PM  131.82  129.94  ETHUSD
# 1   2020-03-13 07-PM  132.02  119.51  ETHUSD
# 2   2020-03-13 06-PM  124.85  124.47  ETHUSD
# 3   2020-03-13 05-PM  127.42  124.08  ETHUSD
# 4   2020-03-13 04-PM  129.51  124.85  ETHUSD
# 5   2020-03-13 03-PM  128.90  128.39  ETHUSD
# 6   2020-03-13 02-PM  137.90  134.03  ETHUSD
# 7   2020-03-13 01-PM  140.95  131.35  ETHUSD
# 8   2020-03-13 12-PM  134.60  128.93  ETHUSD
# 9   2020-03-13 11-AM  133.17  132.60  ETHUSD
# 10  2020-03-13 10-AM  134.99  133.80  ETHUSD

# %%
stock_df['Open']
# Out:
# 0        129.94
# 1        119.51
# 2        124.47
# 3        124.08
# 4        124.85
#           ...
# 23669    265.74
# 23670    268.79
# 23671    274.83
# 23672    275.01
# 23673    279.98
# Name: Open, Length: 23674, dtype: float64

# %%
l=[1,2,3,4,5]
l[1:4] #slicing a list
# Out:
# [2, 3, 4]

# %%
d2=[[1,2,3],
    [4,5,6],
    [7,8,9]]
d2
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
d2
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# Slicing in loc(labaled location)

# %%
stock_df.loc[10,'Date':'High']
# Out:
# Date      2020-03-13 10-AM
# Symbol              ETHUSD
# Open                 133.8
# High                134.99
# Name: 10, dtype: object

# %% [markdown]
# ### iloc - index based location,when we dont konw lables for row and colmns

# %%
stock_df.iloc

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
stock_df.iloc[2:2]
# Out:
# Empty DataFrame
# Columns: [Date, Symbol, Open, High, Low, Close, Volume]
# Index: []

# %%
stock_df.iloc[2,2]
# Out:
# np.float64(124.47)

# %%
stock_df.iloc[2,2:5] #multiple siciling
# Out:
# Open    124.47
# High    124.85
# Low      115.5
# Name: 2, dtype: object

# %%
stock_df.iloc[3,[2,4]]
# Out:
# Open    124.08
# Low     121.63
# Name: 3, dtype: object

# %%
stock_df.iloc[1:6,2:6]
# Out:
#      Open    High     Low   Close
# 1  119.51  132.02  117.10  129.94
# 2  124.47  124.85  115.50  119.51
# 3  124.08  127.42  121.63  124.47
# 4  124.85  129.51  120.17  124.08
# 5  128.39  128.90  116.06  124.85

# %%
stock_df['High']>100
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 23669    True
# 23670    True
# 23671    True
# 23672    True
# 23673    True
# Name: High, Length: 23674, dtype: bool

# %%
f1=stock_df['High']>100

stock_df[f1]
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23375 rows x 7 columns]

# %%
stock_gt_130=stock_df

# %%
stock_gt_130
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
stock_gt_130.reset_index(drop=True,inplace=True)

# %%
stock_gt_130.reset_index(drop=True)
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
stock_df.index
# Out:
# RangeIndex(start=0, stop=23674, step=1)

# %%
stock_df.iloc[len(stock_df)-1]
# Out:
# Date      2017-07-01 11-AM
# Symbol              ETHUSD
# Open                279.98
# High                279.99
# Low                  272.1
# Close               275.01
# Volume           679358.87
# Name: 23673, dtype: object

# %%
len(stock_df)
# Out:
# 23674

# %%
stock_df['Random_col'] = list(range(1,len(stock_df)+1))

# %%
stock_df['Random_col'] =range(1,len(stock_df)+1)

# %% [markdown]
# dropping coloum

# %%
stock_df.drop(columns=['Random_col'])
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
stock_df.drop(columns=['Random_col'],inplace=True)

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
stock_df.drop(columns=['Open','High'],inplace=True)

# %%
stock_df.drop(23456,axis=0,inplace=True)

# %% [markdown]
# Dropping row
